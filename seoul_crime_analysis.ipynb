# %% [markdown]
# CCTV 데이터 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-2734&srvType=C&serviceKind=1&currentPageNo=1
#
# 1. '서울시 자치구 년도별 CCTV 설치 현황(2011년 이전~2018년).xlsx 다운
# 2. '서울시 CCTV.xlsx'로 저장 & 파일 열기
# 3. 2018년 컬럼 삭제 & 저장
#
# 범죄발생수 데이터 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=316&srvType=S&serviceKind=2
#
# 1. 기간 탭에서 년 > 2017년 ~ 2017년으로 설정
# 2. '자료검색' 클릭, 'XLS' 클릭 & 다운
# 3. '서울시 범죄빈도.xls'로 저장
#
# 여성가구 데이터 -- https://data.seoul.go.kr/dataList/datasetView.do?serviceKind=2&infId=419&srvType=S&stcSrl=419
#
# 1. 기간 탭에서 년 > 2017년 ~ 2017년으로 설정
# 2. '자료검색' 클릭, 'XLS' 클릭 & 다운
# 3. '서울시 여성인구.xls'로 저장
#
# 주요기관 데이터 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=224&srvType=S&serviceKind=2
#
# 1. 기간 탭에서 년 > 2017년 ~ 2017년으로 설정
# 2. '자료검색' 클릭, 'XLS' 클릭 & 다운
# 3. '서울시 주요기관.xls'로 저장 & 파일 열기
# 4. 맨 끝에 '합계' 컬럼 생성
# 5. I2 셀 클릭 > 함수 삽입 아이콘 클릭(fx) > SUM 선택 > Number1 칸에 C2:H2 입력
# 6. I2 셀을 다시 클릭 > 오른쪽 밑에 커서를 대고 검은색 십자가 모양이 되면 강동구까지 드래그해줌 > 저장
#
#
# 유흥업소 데이터
#
# 1. 강남구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-11281&srvType=S&serviceKind=1&currentPageNo=1
# 2.  강동구-- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10665&srvType=S&serviceKind=1&currentPageNo=1
# 3.  강북구-- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10896&srvType=S&serviceKind=1&currentPageNo=1
# 4.  강서구-- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-9972&srvType=S&serviceKind=1&currentPageNo=1
# 5.  관악구-- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-11512&srvType=S&serviceKind=1&currentPageNo=1
# 6.  광진구-- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-9895&srvType=S&serviceKind=1&currentPageNo=1
# 7.  구로구-- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-2308&srvType=S&serviceKind=1&currentPageNo=1
# 8.  금천구-- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10126&srvType=S&serviceKind=1&currentPageNo=1
# 9.  노원구-- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10973&srvType=S&serviceKind=1&currentPageNo=1
# 10. 도봉구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10049&srvType=S&serviceKind=1&currentPageNo=1
# 11. 동대문구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10357&srvType=S&serviceKind=1&currentPageNo=1
# 12. 동작구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10588&srvType=S&serviceKind=1&currentPageNo=1
# 13. 마포구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-11358&srvType=S&serviceKind=1&currentPageNo=1
# 14. 서대문구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-2345&srvType=S&serviceKind=1&currentPageNo=1
# 15. 서초구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-11050&srvType=S&serviceKind=1&currentPageNo=1
# 16. 성동구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10742&srvType=S&serviceKind=1&currentPageNo=1
# 17. 성북구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-11127&srvType=S&serviceKind=1&currentPageNo=1
# 18. 송파구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-11435&srvType=S&serviceKind=1&currentPageNo=1
# 19. 양천구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10819&srvType=S&serviceKind=1&currentPageNo=1
# 20. 양등포구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10434&srvType=S&serviceKind=1&currentPageNo=1
# 21. 용산구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-11204&srvType=S&serviceKind=1&currentPageNo=1
# 22. 은평구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10511&srvType=S&serviceKind=1&currentPageNo=1
# 23. 종로구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-9818&srvType=S&serviceKind=1&currentPageNo=1
# 24. 중구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10203&srvType=S&serviceKind=1&currentPageNo=1
# 25. 중랑구 -- https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-10280&srvType=S&serviceKind=1&currentPageNo=1
#
#
# (블로그) 서울시 지도 데이터 -- https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo.json
# 1. 'TL_SCCO_SIG.json' 다운 -- 전국 시군구 데이터
# 2. 서울시 데이터만 추출하여 다른 파일로 저장 ('서울시 지도.json')
#
# ★ 서울시 2017년 후반 데이터로 통일시킴

# %% [markdown]
# <br>★ 모듈 설치</br>
# <br>pip install pandas</br>
# <br>pip install numpy</br>
# <br>pip install glob</br>
# <br>pip install warnings</br>
# <br>pip install folium</br>
# <br>pip install tqdm</br>
# <br>pip install geocoder</br>
# <br>pip install paramiko</br>
# <br>pip install xlrd</br>
# <br>pip install xlwt</br>

# %%
import pandas as pd
import numpy as np
from glob import glob
import warnings
import json
import folium
from tqdm import tqdm_notebook as tqdm
import geocoder
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import seaborn as sns
from functools import reduce
warnings.simplefilter(action="ignore", category=FutureWarning)

#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-<경로 지정>
cctv = 'E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\서울시 CCTV.xlsx'
crime = 'E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\서울시 범죄빈도.xls'
population = 'E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\서울시 인구.xls'
police_station = 'E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\서울시 주요기관.xls'
entertainment_spot = glob('E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\서울시 유흥업소\\서울시*.xls')

# %% [markdown]
# # CCTV 데이터 정리

# %%
seoul_cctv = pd.read_excel(cctv, header=0, usecols='A, B')
seoul_cctv.rename(columns={seoul_cctv.columns[0] : '자치구', seoul_cctv.columns[1]: 'CCTV 개수'}, inplace=True)

gu_data = seoul_cctv['자치구'].unique()
gu_info = []
for gu in gu_data:
    gu = gu.replace(' ', '')  # 문자 사이에 공백 제거
    gu_info.append(gu)

seoul_cctv['자치구'] = gu_info
seoul_cctv
# Out:
#      자치구  CCTV 개수
# 0    강남구     4773
# 1    강동구     1494
# 2    강북구      946
# 3    강서구     1363
# 4    관악구     3314
# 5    광진구     1235
# 6    구로구     2741
# 7    금천구     1104
# 8    노원구     1750
# 9    도봉구      787
# 10  동대문구     1806
# 11   동작구     1525
# 12   마포구     1935
# 13  서대문구     1927
# 14   서초구     2439
# 15   성동구     2385
# 16   성북구     2360
# 17   송파구     1190
# 18   양천구     1945
# 19  영등포구     1702
# 20   용산구     2063
# 21   은평구     2595
# 22   종로구     1370
# 23    중구     1216
# 24   중랑구     1059

# %% [markdown]
# # 범죄빈도수 데이터 정리

# %%
seoul_crime = pd.read_excel(crime, header=1, usecols='B: D')
seoul_crime = seoul_crime[seoul_crime.자치구 != '합계']  # 합계 행 제거
seoul_crime = seoul_crime.sort_values('자치구')
seoul_crime.rename(columns={seoul_crime.columns[1] : '범죄 발생건수', seoul_crime.columns[2]: '범죄 검거건수'}, inplace=True)

seoul_crime
# Out:
#      자치구  범죄 발생건수  범죄 검거건수
# 23   강남구     7720     5321
# 25   강동구     4261     3245
# 9    강북구     3393     2824
# 16   강서구     5135     3927
# 21   관악구     5525     4154
# 5    광진구     4646     3289
# 17   구로구     4895     3408
# 18   금천구     3265     2572
# 11   노원구     4209     3047
# 10   도봉구     1999     1652
# 6   동대문구     3975     3274
# 20   동작구     3330     2242
# 14   마포구     5278     3499
# 13  서대문구     3113     2299
# 22   서초구     4708     3237
# 4    성동구     2767     2031
# 8    성북구     3434     2479
# 24   송파구     5576     3870
# 15   양천구     3882     2660
# 19  영등포구     5969     4012
# 3    용산구     4060     2936
# 12   은평구     3883     3207
# 1    종로구     4057     4437
# 2     중구     4184     2851
# 7    중랑구     4571     3392

# %% [markdown]
# # 여성인구 데이터 정리

# %%
seoul_female_pop = pd.read_excel(population, header=2, usecols='B, F')
seoul_female_pop = seoul_female_pop[seoul_female_pop.자치구 != '합계']
seoul_female_pop = seoul_female_pop.sort_values('자치구')
seoul_female_pop.rename(columns={seoul_female_pop.columns[1] : '여성인구'}, inplace=True)

seoul_female_pop
# Out:
#      자치구    여성인구
# 23   강남구  292111
# 25   강동구  221660
# 9    강북구  167750
# 16   강서구  312080
# 21   관악구  258923
# 5    광진구  191653
# 17   구로구  220173
# 18   금천구  123716
# 11   노원구  287050
# 10   도봉구  176681
# 6   동대문구  184826
# 20   동작구  209666
# 14   마포구  202535
# 13  서대문구  169778
# 22   서초구  231979
# 4    성동구  158634
# 8    성북구  234304
# 24   송파구  344766
# 15   양천구  240739
# 19  영등포구  199624
# 3    용산구  125021
# 12   은평구  252979
# 1    종로구   84163
# 2     중구   68256
# 7    중랑구  207655

# %% [markdown]
# # 경찰서/소방서 등의 데이터 정리

# %%
police = pd.read_excel(police_station, header=0, usecols='B, I')
police = police[police.자치구 != '합계']  # 합계 행 제거
seoul_police = police.sort_values('자치구')
seoul_police.rename(columns={seoul_police.columns[1] : '안전관련 공공기관 개수'}, inplace=True)
# 안전관련 공공기관 개수 = 경찰청 + 경찰서 + 지구대파출소치안센터 + 소방본부 + 소방서 + 119안전센터

seoul_police
# Out:
#      자치구  안전관련 공공기관 개수
# 23   강남구            32
# 25   강동구            24
# 9    강북구            21
# 16   강서구            19
# 21   관악구            26
# 5    광진구            16
# 17   구로구            25
# 18   금천구            15
# 11   노원구            26
# 10   도봉구            16
# 6   동대문구            28
# 20   동작구            23
# 14   마포구            25
# 13  서대문구            18
# 22   서초구            28
# 4    성동구            21
# 8    성북구            31
# 24   송파구            29
# 15   양천구            24
# 19  영등포구            22
# 3    용산구            19
# 12   은평구            27
# 1    종로구            32
# 2     중구            28
# 7    중랑구            24

# %% [markdown]
# # 유흥업소 데이터 정리

# %%
raw = []

for entertainment in entertainment_spot:
    gu_ent = pd.read_excel(entertainment, header=0)
    gu_name = gu_ent['소재지도로명'][0].split()[1]
    gu_ent['자치구'] = gu_name
    
    new_gu_ent = pd.DataFrame({'업소명': gu_ent['업소명'], '자치구': gu_ent['자치구'], '폐업일자': gu_ent['폐업일자']})
    new_gu_ent.drop_duplicates(subset='업소명', keep='first', inplace=True)  # 중복된 것을 삭제 (모두 삭제하지 않고 첫 번째꺼는 남겨둠)
    raw.append(new_gu_ent)
    
gu_combined = pd.concat(raw)
gu_combined.to_excel('서울시 유흥업소.xls')  # 만든 표를 새로운 엑셀 파일로 저장 (경로는 C:\Users\username)

#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-<경로 지정>
seoul_entertainment = pd.read_excel('E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\서울시 유흥업소.xls', header = 0)
closed = seoul_entertainment[pd.notnull(seoul_entertainment['폐업일자'])]  # 폐업한 주점들 (폐업일자란이 비어있지 않은 것들)
closed_before_2017 = seoul_entertainment[seoul_entertainment['폐업일자'] <= 20170000].index  # 2017년 이전에 폐업한 주점들
seoul_entertainment = seoul_entertainment.drop(closed_before_2017)

seoul_ent = pd.DataFrame({'자치구': seoul_entertainment['자치구']})
count_gu = seoul_ent.groupby('자치구').size()
seoul_ent = count_gu.to_frame().reset_index()
seoul_ent.rename(columns={seoul_ent.columns[1] : '유흥업소 개수'}, inplace=True)

seoul_ent
# Out:
#      자치구  유흥업소 개수
# 0    강남구      362
# 1    강동구      156
# 2    강북구       84
# 3    강서구      168
# 4    관악구      249
# 5    광진구       21
# 6    구로구       43
# 7    금천구       62
# 8    노원구       33
# 9    도봉구       27
# 10  동대문구       90
# 11   동작구       54
# 12   마포구       69
# 13  서대문구       33
# 14   서초구       96
# 15   성동구       25
# 16   성북구        9
# 17   송파구      134
# 18   양천구        7
# 19  영등포구      186
# 20   용산구       32
# 21   은평구       94
# 22   종로구      225
# 23    중구      268
# 24   중랑구       33

# %% [markdown]
# # 서울시 지도 그리기 & CCTV 개수에 따라 색 지정

# %%
bing_key = 'Aiydk3nEeyClRHaGHHuXXhMszPDk9bEtIaueXe2IyL83gpsRncbfcIV8ciMp1aNu'
latitude = []
longitude = []

for gu in tqdm(gu_info):
    tmp_map = geocoder.bing('서울시 ' + gu, key=bing_key)
    gu_lat = tmp_map.latlng[0]
    gu_long = tmp_map.latlng[1]
    
    latitude.append(gu_lat)
    longitude.append(gu_long)

#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-<경로 지정>
geo_path = 'E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\서울시 지도.json'
geo_data = json.load(open(geo_path, encoding='cp949'))

map = folium.Map(location=[37.5286315,126.9042924], zoom_start=10.5, tiles='OpenStreetMap')
map.choropleth(geo_data=geo_data,
              data=seoul_cctv, columns=['자치구', 'CCTV 개수'],
              fill_color='YlOrBr',
              key_on='properties.name')

for i in range(len(gu_info)):
    gu = gu_info[i]
    folium.Marker(location=[latitude[i], longitude[i]], tooltip=gu).add_to(map)
    
map
# Out:
# ...
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 자치구에 따른 데이터 합치기

# %%
seoul_info = [seoul_crime, seoul_cctv, seoul_female_pop, seoul_police, seoul_ent]
seoul_info = reduce(lambda left, right: pd.merge(left, right, on='자치구'), seoul_info)

seoul_info

# %% [markdown]
# # 상관계수

# %%
np.corrcoef(seoul_info['범죄 발생건수'],seoul_info['CCTV 개수'])

# %%
np.corrcoef(seoul_info['범죄 발생건수'],seoul_info['유흥업소 개수'])

# %%
np.corrcoef(seoul_info['범죄 발생건수'],seoul_info['여성인구'])

# %%
np.corrcoef(seoul_info['범죄 발생건수'],seoul_info['안전관련 공공기관 개수'])
# Out:
# array([[1.        , 0.44595531],
#        [0.44595531, 1.        ]])

# %% [markdown]
# # 상관계수에 따른 표 생성

# %%
#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-#-<경로 지정>
font_path = 'E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', size=15, family = font_name)

# %%
plt.figure(figsize=(20, 15))
heatmap = sns.heatmap(data = seoul_info.corr(), annot=True, annot_kws={'size': 20}, fmt = '.2f', linewidths=.5, cmap='Blues')
heatmap.set_ylim(6, 0)
heatmap.set_yticklabels( ['범죄 발생건수', '범죄 검거건수', 'CCTV 개수', '여성인구', '안전관련 공공기관 개수', '유흥업소 개수'], va='center')
plt.show()

# %% [markdown]
# # 구별 범죄 발생건수 그래프

# %%
seoul_info.set_index('자치구', inplace=True)  # 인덱스를 자치구로 지정, 인덱스를 정해주지 않으면 그래프 세로축이 구 이름이 아닌 숫자로 나옴
seoul_info['범죄 발생건수'].sort_values().plot.barh(grid=True, figsize=(10, 12))
plt.show() #범죄 발생건수를 기준으로 내림차순 정렬

# %% [markdown]
# # 범죄 발생건수와 CCTV 개수의 상관관계 그래프

# %%
plt.figure(figsize=(6, 6))
plt.scatter(seoul_info['범죄 발생건수'], seoul_info['CCTV 개수'], s=50)  # 두 개의 실수 데이터 집합의 상관관계를 보여줌
plt.xlabel('범죄 발생건수')
plt.ylabel('CCTV 개수')
plt.grid()
plt.show()

# %%
line1 = np.polyfit(seoul_info['범죄 발생건수'], seoul_info['CCTV 개수'], 1)  # 최소오차 직선 생성 (기울기 & y 절편 반환)
line1
# Out:
# array([  0.40764474, 122.62516223])

# %%
crime_cctv = np.poly1d(line1)  # x의 계수를 대입하여 방정식 생성
fx = np.linspace(2000, 8000, 1000)  # (시작점, 끝지점, 그 사이에 존재할 숫자의 개수)를 통해 x축 데이터 생성
plt.figure(figsize=(10, 10))
plt.scatter(seoul_info['범죄 발생건수'], seoul_info['CCTV 개수'], s=50)
plt.plot(fx, crime_cctv(fx), ls='dashed', lw=3, color='g')
plt.xlabel('범죄 발생건수')
plt.ylabel('CCTV 개수')
plt.grid()
plt.show()

# %% [markdown]
# # 범죄 발생건수와 여성인구의 상관관계 그래프

# %%
plt.figure(figsize=(6, 6))
plt.scatter(seoul_info['범죄 발생건수'], seoul_info['여성인구'], s=50)  # 두 개의 실수 데이터 집합의 상관관계를 보여줌
plt.xlabel('범죄 발생건수')
plt.ylabel('여성인구')
plt.grid()
plt.show()

# %%
line2 = np.polyfit(seoul_info['범죄 발생건수'], seoul_info['여성인구'], 1)
line2
# Out:
# array([2.80038000e+01, 8.58772891e+04])

# %%
crime_female = np.poly1d(line2)
fx = np.linspace(2000, 8000, 1000)
plt.figure(figsize=(10, 10))
plt.scatter(seoul_info['범죄 발생건수'], seoul_info['여성인구'], s=50)
plt.plot(fx, crime_female(fx), ls='dashed', lw=3, color='g')
plt.xlabel('범죄 발생건수')
plt.ylabel('여성인구')
plt.grid()
plt.show()

# %% [markdown]
# # 범죄 발생건수와 안전관련 공공기관 개수의 상관관계 그래프

# %%
plt.figure(figsize=(6, 6))
plt.scatter(seoul_info['범죄 발생건수'], seoul_info['안전관련 공공기관 개수'], s=50)
plt.xlabel('범죄 발생건수')
plt.ylabel('안전관련 공공기관 개수')
plt.grid()
plt.show()

# %%
line3 = np.polyfit(seoul_info['범죄 발생건수'], seoul_info['안전관련 공공기관 개수'], 1)
line3
# Out:
# array([1.87493514e-03, 1.58726548e+01])

# %%
crime_safety = np.poly1d(line3)  
fx = np.linspace(2000, 8000, 1000) 
plt.figure(figsize=(10, 10))
plt.scatter(seoul_info['범죄 발생건수'], seoul_info['안전관련 공공기관 개수'], s=50)
plt.plot(fx, crime_safety(fx), ls='dashed', lw=3, color='g')
plt.xlabel('범죄 발생건수')
plt.ylabel('안전관련 공공기관 개수')
plt.grid()
plt.show()

# %% [markdown]
# # 범죄 발생건수와 유흥업소 개수의 상관관계 그래프

# %%
plt.figure(figsize=(6, 6))
plt.scatter(seoul_info['범죄 발생건수'], seoul_info['유흥업소 개수'], s=50)
plt.xlabel('범죄 발생건수')
plt.ylabel('유흥업소 개수')
plt.grid()
plt.show()

# %%
line4 = np.polyfit(seoul_info['범죄 발생건수'], seoul_info['유흥업소 개수'], 1)
line4
# Out:
# array([ 5.31480874e-02, -1.26848960e+02])

# %%
crime_ent = np.poly1d(line4)  
fx = np.linspace(2000, 8000, 1000) 
plt.figure(figsize=(10, 10))
plt.scatter(seoul_info['범죄 발생건수'], seoul_info['유흥업소 개수'], s=50)
plt.plot(fx, crime_ent(fx), ls='dashed', lw=3, color='g')
plt.xlabel('범죄 발생건수')
plt.ylabel('유흥업소 개수')
plt.grid()
plt.show()

# %% [markdown]
# cmd창에 다음을 입력하면 html 파일을 저장해줌
# <br>jupyter nbconvert --to html --TemplateExporter.exclude_input=True seoul_crime_analysis.ipynb</br>

# %%
import paramiko
import os

def ipynb_to_html():
    #경로에 맞게 변경
    os.system("E:")
    os.system("cd E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드")
    os.system("jupyter nbconvert --to html --TemplateExporter.exclude_input=True seoul_crime_analysis.ipynb")


def transfer_to_server():
    # Open a transport
    host = "kpubigdata.synology.me"
    port = 3117
    transport = paramiko.Transport((host, port))

    # Auth
    password = "kputest!" #나스 비밀번호
    username = "analysis" #나스 아이디
    transport.connect(username = username, password = password)

    # Go!

    sftp = paramiko.SFTPClient.from_transport(transport)

    # Download filepath = '/etc/passwd' localpath = '/home/remotepasswd' sftp.get(filepath, localpath)
    #Upload
    filepath = '/web/analysis.html' #서버의 주소
    localpath = 'E:\\팡팡NAS\\Bigdata 과제\\인력양성\\2019\\02 시큐리티팀\\소스코드\\seoul_crime_analysis.html' #보낼 파일의 로컬 주소(경로에 맞게 수정)
    sftp.put(localpath, filepath)

    # Close
    sftp.close()
    transport.close()

ipynb_to_html()
transfer_to_server()
